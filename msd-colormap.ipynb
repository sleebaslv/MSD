# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import *
from matplotlib.backends.backend_pdf import PdfPages
import glob
import seaborn as sns
# %matplotlib inline
plt.style.use('seaborn')

filenames = sorted(glob.glob('./with_Fld/*.dat'))
data_nofld = np.loadtxt('./no_Fld/msd_20_0.001.dat')

n = 27
i=0
j=0
k=0
colors = plt.cm.jet(np.linspace(0,1,n))
  
for f in filenames:
    data = np.loadtxt(fname = f)
    tau = range(1,100)
    x = data[:,1]
    plt.plot(tau, x, color=colors[i], label=f)
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    plt.xlabel("tau")
    plt.ylabel("$MSD_{X}$")
    i =i+1
#plt.savefig('msd_comb.pdf')
x_nofld = data[:,1]
plt.plot(tau, x_nofld, '--k', label='nofld')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

  
for f in filenames:
    data = np.loadtxt(fname = f)
    tau = range(1,100)
    y = data[:,2]
    plt.plot(tau, y, color=colors[j], label=f)
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    plt.xlabel("tau")
    plt.ylabel("$MSD_{Y}$")
    j =j+1
#plt.savefig('msd_comb.pdf')
y_nofld = data[:,2]
plt.plot(tau, y_nofld, '--k', label='nofld')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

  
for f in filenames:
    data = np.loadtxt(fname = f)
    tau = range(1,100)
    z = data[:,3]
    plt.plot(tau, z, color=colors[i], label=f)
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    plt.xlabel("tau")
    plt.ylabel("$MSD_{Z}$")
    k =k+1
z_nofld = data[:,3]
plt.plot(tau, z_nofld, '--k', label='nofld')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
#plt.savefig('msd_comb.pdf')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import *
from matplotlib.backends.backend_pdf import PdfPages
import glob
import seaborn as sns
# %matplotlib inline
plt.style.use('seaborn')

filenames = sorted(glob.glob('./with_Fld/*.dat'))
n = 27
i=0
j=0
k=0
colors = plt.cm.jet(np.linspace(0,1,n))
  
for f in filenames:
    data = np.loadtxt(fname = f)
    tau = range(1,100)
    x = data[:,1]
    plt.plot(tau, x, color=colors[i], label=f)
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    plt.xlabel("tau")
    plt.ylabel("$MSD_{X}$")
    i =i+1
#plt.savefig('msd_comb.pdf')
plt.show()

  
for f in filenames:
    data = np.loadtxt(fname = f)
    tau = range(1,100)
    y = data[:,2]
    plt.plot(tau, y, color=colors[j], label=f)
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    plt.xlabel("tau")
    plt.ylabel("$MSD_{Y}$")
    j =j+1
#plt.savefig('msd_comb.pdf')
plt.show()

  
for f in filenames:
    data = np.loadtxt(fname = f)
    tau = range(1,100)
    z = data[:,3]
    plt.plot(tau, z, color=colors[i], label=f)
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    plt.xlabel("tau")
    plt.ylabel("$MSD_{Z}$")
    k =k+1
#plt.savefig('msd_comb.pdf')
plt.show()
